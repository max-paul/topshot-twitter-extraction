# %%
import pandas as pd

# %%
cols = ['hashtags','tweet_id','created_at','text','name','user','user_id','user_loc','user_desc','user_followers','user_friends','user_listed','user_created','user_favs','user_verified','user_statuses']
data = pd.read_csv('topgiveaway.csv',header=None)
data.columns = cols

# %%
data.dtypes
# Out:
# hashtags          object
# tweet_id           int64
# created_at        object
# text              object
# name              object
# user              object
# user_id            int64
# user_loc          object
# user_desc         object
# user_followers     int64
# user_friends       int64
# user_listed        int64
# user_created      object
# user_favs          int64
# user_verified       bool
# user_statuses      int64
# dtype: object

# %% [markdown]
# - topshot usernames must be between 3 and 30 chars
# - assume most names no that long
# - take 30 spaces after then clean again?

# %%
data.head()
# Out:
#   hashtags             tweet_id                      created_at  \
# 0       []  1382335475181002752  Wed Apr 14 14:10:34 +0000 2021
# 1       []  1382335770430746630  Wed Apr 14 14:11:44 +0000 2021
# 2       []  1382335770741067777  Wed Apr 14 14:11:44 +0000 2021
# 3       []  1382335770782953473  Wed Apr 14 14:11:44 +0000 2021
# 4       []  1382335770858553345  Wed Apr 14 14:11:44 +0000 2021
#
#                                                 text            name  \
# 0  RT @carmine_ssb: GIVEAWAY TIME!! To celebrate ...            Auri
# 1  RT @amustycow: 🎁TW FENNEC GIVEAWAY🎁\r\n\r\nto ...           Quinn
# 2  RT @BilalMunir1995: Biggest Cellphone Giveaway...  Irtaza Qureshi
# 3  RT @yixieforever: 飄飄 trying hard to win giveaw...  Cream star1 TH
# 4  RT @DonkTrading: 🚨 10x Patreon spot giveaway 🚨...          Quaver
#
#              user              user_id           user_loc  \
# 0   Unorthodox444  1038444719812927489  Edmonton, Alberta
# ...
